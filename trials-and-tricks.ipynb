# %%
def hello(name: str):
    print(f'Hello {name}')
    
hello("Raoul")

# %%
import random
def fetch_page(page: int = 0):
    next_page: int = 0
    next_page = page + 1
    MAX = random.randint(1, 10)
    return {"next_page": next_page, "result": random.sample(range(1,30),MAX)}
print(fetch_page(0))

def get_result(number_of_elts: int = 0):
    page = 0
    elements = []
    if number_of_elts == 0:
        return []
    while True:
        get_page_info = fetch_page(page)
        if number_of_elts > len(get_page_info["result"]):
            elements.extend(get_page_info["result"])
        else:
            elements.extend(get_page_info["result"][:number_of_elts])
        page +=1
        number_of_elts -= len(get_page_info["result"])
        if number_of_elts <= 0 or get_page_info["next_page"] == 0:
            return elements

get_result(1)

# %%
  def isPalindrome(x):
        if x < 0:
            return False
        reversed_number = 0
        number = x
        while x > 0:
            digit = x % 10
            x = x // 10
            print(f"digit = {digit} and x = {x}")
            reversed_number = reversed_number * 10 + digit
            print(f'reversed_number = {reversed_number}')

        return number == reversed_number
isPalindrome(121)

# %%
def romanToInt(s: str) -> int:
    DictRomanNum = {
        "I": 1, 
        "V": 5,
        "X": 10,
        "L": 50,
        "C": 100,
        "D": 500,
        "M": 1000
    }
    result = DictRomanNum[s[len(s) - 1]]
    for idx in range(len(s) - 1):
        if DictRomanNum[s[idx]] < DictRomanNum[s[idx+1]]:
            result -= DictRomanNum[s[idx]]
        else:
            result += DictRomanNum[s[idx]]
    return result
        

romanToInt("MCMXCIV")

# %%
"""
Example 1:

Input: s = "III"
Output: 3
Explanation: III = 3.
Example 2:

Input: s = "LVIII"
Output: 58
Explanation: L = 50, V= 5, III = 3.
Example 3:

Input: s = "MCMXCIV" 2 * M + C + V 2105 - 111
Output: 1994
Explanation: M = 1000, CM = 900, XC = 90 and IV = 4."
"""

# %%
'''Self Check

Here’s a self check that really covers everything so far. 
You may have heard of the infinite monkey theorem? 
The theorem states that a monkey hitting keys at random on a typewriter keyboard 
for an infinite amount of time will almost surely type a given text,
such as the complete works of William Shakespeare. Well, suppose we replace a monkey with a Python function. 
How long do you think it would take for a Python function to generate just one sentence of Shakespeare? 
The sentence we’ll shoot for is: “methinks it is like a weasel”

You’re not going to want to run this one in the browser, so fire up your favorite Python IDE. 
The way we’ll simulate this is to write a function that generates a string that is 28 characters long by choosing random letters
from the 26 letters in the alphabet plus the space.
We’ll write another function that will score each generated string by comparing the randomly generated string to the goal.

A third function will repeatedly call generate and score, then if 100% of the letters are correct we are done. 
If the letters are not correct then we will generate a whole new string.To make it easier to follow your program’s progress 
this third function should print out the best string generated so far and its score every 1000 tries
'''

import random
import string

def monkey_typewriter(num: int) -> list:
    """Generate a list of letters of num numbers"""
    alphabet = 'abcdefghijklmnopqrstuvwxyz1' #26 letters of the alphabet + space
    res = []
    for i in range(num):
        res.append(alphabet[random.randrange(27)])
    return res

def score(word_to_find: list, guess_word: list) -> int:
    """Get you a score based on the letter guessed right"""
    char_matched=0
    length_guess_word=len(guess_word)
    for count in range(length_guess_word):
        if word_to_find[count] == guess_word[count]:
            char_matched+=1
    return char_matched/length_guess_word


def main():
    if __name__ == '__main__':
        word_to_guess = "methinks it is like a weasel"
        lst_word_to_guess = list(word_to_guess)
        retries = 100
        best_score=0
        total_length = len(lst_word_to_guess)
        for i in range(retries):
            guessed_word = monkey_typewriter(total_length)
            current_score = score(guessed_word, word_to_guess)
            if current_score == 1.0:
                print("Good Job, you guessed it right..")
                break
            if current_score > best_score:
                best_score = current_score
                best_word = ''.join(guessed_word)
        print(f"your best guess so far is {best_score:.2f} with the sentence \"{best_word}\"")
main()
# Out:
# your best guess so far is 0.38 with the sentence "mpthxdwe"

# %%
"""
Self Check Challenge

See if you can improve upon the program in the self check 
by keeping letters that are correct and only modifying one character in the best string so far. 
This is a type of algorithm in the class of ‘hill climbing’ algorithms, 
that is we only keep the result if it is better than the previous one.
"""
import random
import string

def monkey_typewriter(word_to_find: list, best_thing: list) -> list:
    """Generate a list of letters of num numbers"""
    alphabet = 'abcdefghijklmnopqrstuvwxyz ' #26 letters of the alphabet + space
    res = []
    if len(best_thing) == 0:
        for i in range(len(word_to_find)):
            res+=alphabet[random.randrange(27)]
        return res
    else:
        for i in range(len(word_to_find)):
            if best_thing[i] != word_to_find[i]:
                best_thing[i] = alphabet[random.randrange(27)]
        return best_thing
            

def score(word_to_find: list, guess_word: list) -> float:
    """Get you a score based on the letter guessed right"""
    char_matched=0.0
    length_guess_word=len(word_to_find)
    for count in range(length_guess_word):
        if word_to_find[count] == guess_word[count]:
            char_matched+=1.0
    return float(char_matched/length_guess_word)

def main():
    if __name__ == '__main__':
        word_to_guess = "methinks it is like a weasel"
        retries = 100
        best_score=0.0
        guessed_word=[]
        best_word=""
        num_retries = 0
        total_length = len(word_to_guess)
        for i in range(retries):
            guessed_word = monkey_typewriter(word_to_guess, guessed_word)
            current_score = score(word_to_guess, guessed_word)
            # Need to compare the current_score to the best_score because we need to know
            # to ensure if the current score is not better than the best score currently stored
            if current_score > best_score:
                best_score = current_score
                best_word = ''.join(guessed_word)
                num_retries = i
            if best_score == 1.0:
                print("Good Job, you guessed it right..")
                break
        print(f"your best guess so far is {best_score:.4f} with the sentence \"{best_word}\" on number of retries of {num_retries}")
main()
# Out:
# Good Job, you guessed it right..
# your best guess so far is 1.0000 with the sentence "methinks it is like a weasel" on number of retries of 98

# %%
import random
import string
print(random.choices(string.ascii_lowercase + " ", k=1))

# %%
alphabet = 'abcdefghijklmnopqrstuvwxyz '
alphabet[random.randrange(27)]

# %%
sample_list = [1,2,3]
sample_list2 = [4,5,6]
sample_list += sample_list2
print(sample_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
"""Example to create the error: TypeError: 'NoneType' object is not subscriptable"""
my_list = [40,20,10,30,50]

my_sorted_list = my_list.sort()

print(my_sorted_list[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12888\3699358469.py in <module>
#       3 my_sorted_list = my_list.sort()
#       4
# ----> 5 print(my_sorted_list[2])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
""" Solutions to: Example to create the error: TypeError: 'NoneType' object is not subscriptable"""
my_list = [40,20,10,30,50]

my_list.sort()
my_sorted_list = my_list[2]

print(my_sorted_list)
# Out:
# 30

# %%
### OOP
'''
Self Check

To make sure you understand how operators are implemented in Python classes, and how to properly write methods, 
write some methods to implement *, /, and - . Also implement comparison operators > and < 
'''
def gcd(m,n):
    while m%n != 0:
        oldm = m
        oldn = n
        m = oldn
        n = oldm%oldn
    return n

class Fraction:
    def __init__(self, top, bottom):
        self.num= top
        self.den=bottom
    
    ## using a custom def show to print the fraction
    def show(self):
        print(f"{str(self.num)}/{str(self.den)}")
    ## -- Implement the simple methods getNum and getDen that will return the numerator and denominator of a fraction.
    def getNum(self):
        return self.num
    def getDen(self):
        return self.den
    ## using a custom def show to print the fraction
    def show(self):
        print(f"{str(self.num)}/{str(self.den)}")

    ## To allow print to work properly we need to __str__ which tells print what proper string to print
    def __str__(self):
        return str(self.num)+"/"+str(self.den)
    ## implement the operations of adding two fractions
    
    def __add__(self, other_Fraction):
        new_num = self.num * other_Fraction.den + self.den * other_Fraction.num
        new_den = self.den * other_Fraction.den
        common = gcd(new_num, new_den)
        return Fraction(new_num//common, new_den//common)
    
    def __eq__(self, other):
        firstNum = self.num * other.den
        secondNum = self.den * other.num
        return firstNum == secondNum
    
    def __mul__(self, other_Fraction):
        new_num = self.num * other_Fraction.num
        new_den = self.den * other_Fraction.den
        common = gcd(new_num, new_den)
        return Fraction(new_num//common, new_den//common)
    
    def __truediv__(self, other_Fraction):
        new_num = self.num * other_Fraction.den
        new_den = self.den * other_Fraction.num
        common = gcd(new_num, new_den)
        return Fraction(new_num//common, new_den//common)
    
    def __sub__(self, other_Fraction):
        new_num = self.num * other_Fraction.den - self.den * other_Fraction.num
        new_den = self.den * other_Fraction.den
        common = gcd(new_num, new_den)
        return Fraction(new_num//common, new_den//common)
    
    def __lt__(self, other_Fraction):
        firstNum = self.num * other_Fraction.den
        secondNum = self.den * other_Fraction.num
        return firstNum < secondNum
    
    def __gt__(self, other_Fraction):
        firstNum = self.num * other_Fraction.den
        secondNum = self.den * other_Fraction.num
        return firstNum > secondNum
        
    
myfr=Fraction(3,5)
myfr.show()
f1=Fraction(1,4)
f2=Fraction(1,2)
f3=f1+f2
f4=f1-f2
f5=f1*f2
f6=f1/f2

print(myfr)
print(f3)
print(f4)
print(f5)
print(f6)
print(f1>f2)
print(f1<f2)
# Out:
# 3/5
# 3/5
# 3/4
# -1/4
# 1/8
# 1/2
# False
# True

# %%
'''
Self Check

Create a two new gate classes, one called NorGate the other called NandGate. 
NandGates work like AndGates that have a Not attached to the output. 
NorGates work lake OrGates that have a Not attached to the output.

Create a series of gates that prove 
the following equality NOT (( A and B) or (C and D)) is that same as NOT( A and B ) and NOT (C and D). 
Make sure to use some of your new gates in the simulation.
'''

class LogicGate:
    def __init__(self,n):
        self.name = n
        self.output = None

    def getLabel(self):
        return self.name

    def getOutput(self):
        self.output = self.performGateLogic()
        return self.output


class BinaryGate(LogicGate):

    def __init__(self,n):
        super(BinaryGate, self).__init__(n)

        self.pinA = None
        self.pinB = None

    def getPinA(self):
        if self.pinA == None:
            return int(input("Enter Pin A input for gate "+self.getLabel()+"-->"))
        else:
            return self.pinA.getFrom().getOutput()

    def getPinB(self):
        if self.pinB == None:
            return int(input("Enter Pin B input for gate "+self.getLabel()+"-->"))
        else:
            return self.pinB.getFrom().getOutput()

    def setNextPin(self,source):
        if self.pinA == None:
            self.pinA = source
        else:
            if self.pinB == None:
                self.pinB = source
            else:
                print("Cannot Connect: NO EMPTY PINS on this gate")


class AndGate(BinaryGate):

    def __init__(self,n):
        BinaryGate.__init__(self,n)

    def performGateLogic(self):

        a = self.getPinA()
        b = self.getPinB()
        if a==1 and b==1:
            return 1
        else:
            return 0

class OrGate(BinaryGate):

    def __init__(self,n):
        BinaryGate.__init__(self,n)

    def performGateLogic(self):

        a = self.getPinA()
        b = self.getPinB()
        if a ==1 or b==1:
            return 1
        else:
            return 0
        
class NandGate(AndGate):
    def performGateLogic(self):
        if super().performGateLogic() == 1:
            return 0
        else:
            return 1

class NorGate(OrGate):

    def performGateLogic(self):
        if super().performGateLogic() == 1:
            return 0
        else:
            return 1

class UnaryGate(LogicGate):

    def __init__(self,n):
        LogicGate.__init__(self,n)

        self.pin = None

    def getPin(self):
        if self.pin == None:
            return int(input("Enter Pin input for gate "+self.getLabel()+"-->"))
        else:
            return self.pin.getFrom().getOutput()

    def setNextPin(self,source):
        if self.pin == None:
            self.pin = source
        else:
            print("Cannot Connect: NO EMPTY PINS on this gate")


class NotGate(UnaryGate):

    def __init__(self,n):
        UnaryGate.__init__(self,n)

    def performGateLogic(self):
        if self.getPin():
            return 0
        else:
            return 1


class Connector:

    def __init__(self, fgate, tgate):
        self.fromgate = fgate
        self.togate = tgate

        tgate.setNextPin(self)

    def getFrom(self):
        return self.fromgate

    def getTo(self):
        return self.togate


def main():
    #g1 = AndGate("G1")
    #g2 = AndGate("G2")
    #g3 = OrGate("G3")
    #g4 = NotGate("G4")
    #c1 = Connector(g1,g3)
    #c2 = Connector(g2,g3)
    # c3 = Connector(g3,g4)
    #print(g4.getOutput())
    #f2 = AndGate("F2")
    #f1 = NandGate("F1")
    #f3 = OrGate("F3")
    #f4 = NorGate("F4")
    #print(f3.getOutput())
    #print(f4.getOutput())

    ga = AndGate("ga")
    gb = OrGate("gb")
    gc = NotGate("gc")
    gd = NorGate("gd")
    Gab = AndGate("Gab")
    Gcd = AndGate("Gcd")
    Ge = NorGate("Ge")
    NGab = NandGate("NGab")
    NGcd = NandGate("NGcd")
    NGe = AndGate("NGe")
 
    cA = Connector(ga, Gab)
    cB = Connector(gb, Gab)
    cC = Connector(gc, Gcd)
    cd = Connector(gd, Gcd)
    cabe = Connector(Gab, Ge)
    ccde = Connector(Gcd, Ge)
    ncA = Connector(ga, NGab)
    ncB = Connector(gb, NGab)
    ncC = Connector(gc, NGcd)
    ncD = Connector(gd, NGcd)
    ncabe = Connector(NGab, NGe)
    nccde = Connector(NGcd, NGe)
    res1 = Ge.getOutput()
    res2 = NGe.getOutput()
    print(res1)
    print(res2)
    if res1 == res2:
        print("It is proven!!! Youpi")
    else:
        print("You are not yet there! Debug to understand")
main()
# Out:
# Enter Pin A input for gate ga-->1
# Enter Pin B input for gate ga-->1
# Enter Pin A input for gate gb-->1
# Enter Pin B input for gate gb-->0
# Enter Pin input for gate gc-->1
# Enter Pin A input for gate gd-->1
# Enter Pin B input for gate gd-->1
# Enter Pin A input for gate ga-->1
# Enter Pin B input for gate ga-->1
# Enter Pin A input for gate gb-->1
# Enter Pin B input for gate gb-->0
# Enter Pin input for gate gc-->1
# Enter Pin A input for gate gd-->1
# Enter Pin B input for gate gd-->1
# 0
# 0
# It is proven!!! Youpi

# %%
### OOP
'''
Programming Exercises
1. Implement the simple methods getNum and getDen that will return the numerator and denominator of a fraction. done

2. In many ways it would be better if all fractions were maintained in lowest terms right from the start.
   Modify the constructor for the Fraction class so that GCD is used to reduce fractions immediately. 
   Notice that this means the __add__ function no longer needs to reduce. Make the necessary modifications. done

3. Implement the remaining simple arithmetic operators (__sub__, __mul__, and __truediv__). done 

4. Implement the remaining relational operators (__gt__, __ge__, __lt__, __le__, and __ne__). done

5. Modify the constructor for the fraction class so that it checks to make sure that the numerator and denominator are both integers. 
   If either is not an integer the constructor should raise an exception. done

6. In the definition of fractions we assumed that negative fractions have a negative numerator and a positive denominator. 
   Using a negative denominator would cause some of the relational operators to give incorrect results. 
   In general, this is an unnecessary constraint. 
   Modify the constructor to allow the user to pass a negative denominator so that all of the operators continue to work properly. done

7. Research the __radd__ method. How does it differ from __add__? When is it used? Implement __radd__. done

8. Repeat the last question but this time consider the __iadd__ method. done

9. Research the __repr__ method. How does it differ from __str__? When is it used? Implement __repr__. done

10. Research other types of gates that exist (such as NAND, NOR, and XOR). Add them to the circuit hierarchy. 
    How much additional coding did you need to do? done

11. The most simple arithmetic circuit is known as the half-adder. Research the simple half-adder circuit. Implement this circuit.

12. Now extend that circuit and implement an 8 bit full-adder.

13. The circuit simulation shown in this chapter works in a backward direction. 
    In other words, given a circuit, the output is produced by working back through the input values, which in turn cause other outputs to be queried. 
    This continues until external input lines are found, at which point the user is asked for values. 
    Modify the implementation so that the action is in the forward direction; upon receiving inputs the circuit produces an output.

14. Design a class to represent a playing card. Now design a class to represent a deck of cards. 
    Using these two classes, implement a favorite card game.

15. Find a Sudoku puzzle in the local newspaper. Write a program to solve the puzzle.

'''
def gcd(m,n):
    while m%n != 0:
        oldm = m
        oldn = n
        m = oldn
        n = oldm%oldn
    return n

class Fraction:
    def __init__(self, top, bottom):
        if not isinstance(top, int) or not isinstance(bottom, int):
            raise Exception("one or more numbers are not integer")
        if bottom < 0 :
            bottom = bottom * -1
            top = top * -1
        common = gcd(top, bottom)
        self.num = top // common
        self.den = bottom //common
    
    ## using a custom def show to print the fraction
    def show(self):
        print(f"{str(self.num)}/{str(self.den)}")
    ## -- Implement the simple methods getNum and getDen that will return the numerator and denominator of a fraction.
    def getNum(self):
        return self.num
    def getDen(self):
        return self.den
    ## using a custom def show to print the fraction
    def show(self):
        print(f"{str(self.num)}/{str(self.den)}")
    ## To allow print to work properly for debugging purposes we need to __repr__ which tells information about the class.

    def __repr__(self):
        class_name = type(self).__name__
        return f"{class_name}(numerator={self.num!r}, denominator={self.den!r})"
    ## To allow print to work properly we need to __str__ which tells print what proper string to print

    def __str__(self):
        return str(self.num)+"/"+str(self.den)
    ## implement the operations of adding two fractions
    
    def __add__(self, other_Fraction):
        new_num = self.num * other_Fraction.den + self.den * other_Fraction.num
        new_den = self.den * other_Fraction.den
        return Fraction(new_num, new_den)
        
    def __radd__(self, other_Fraction):
        new_num = other_Fraction.den * self.num  +  other_Fraction.num * self.den
        new_den = other_Fraction.den * self.den
        return Fraction(new_num, new_den)
        
    def __iadd__(self, other_Fraction):
        self.num = self.num * other_Fraction.den + self.den * other_Fraction.num
        self.den = self.den * other_Fraction.den
        return Fraction(self.num, self.den)
    
    def __eq__(self, other):
        firstNum = self.num * other.den
        secondNum = self.den * other.num
        return firstNum == secondNum
    
    def __mul__(self, other_Fraction):
        new_num = self.num * other_Fraction.num
        new_den = self.den * other_Fraction.den
        return Fraction(new_num, new_den)
    
    def __truediv__(self, other_Fraction):
        new_num = self.num * other_Fraction.den
        new_den = self.den * other_Fraction.num
        return Fraction(new_num, new_den)
    
    def __sub__(self, other_Fraction):
        new_num = self.num * other_Fraction.den - self.den * other_Fraction.num
        new_den = self.den * other_Fraction.den
        return Fraction(new_num, new_den)
    
    def __lt__(self, other_Fraction):
        firstNum = self.num * other_Fraction.den
        secondNum = self.den * other_Fraction.num
        return firstNum < secondNum
    
    def __gt__(self, other_Fraction):
        firstNum = self.num * other_Fraction.den
        secondNum = self.den * other_Fraction.num
        return firstNum > secondNum
        
    def __le__(self, other_Fraction):
        firstNum = self.num * other_Fraction.den
        secondNum = self.den * other_Fraction.num
        return firstNum <= secondNum
        
    def __ge__(self, other_Fraction):
        firstNum = self.num * other_Fraction.den
        secondNum = self.den * other_Fraction.num
        return firstNum >= secondNum
        
    def __ne__(self, other):
        firstNum = self.num * other.den
        secondNum = self.den * other.num
        return firstNum != secondNum        



myfr=Fraction(3,5)
myfr.show()
f1=Fraction(1,4)
f2=Fraction(1,2)
f3=f1+f2
f3.show()
f1 >= f2
f1 != f2
ft = Fraction(1, -4)
ft1 = Fraction(1, 2)
ft2 = ft + ft1
ft2.show()
ft +=ft1
ft.show()
ft.__repr__()
# Out:
# 3/5
# 3/4
# 1/4
# 1/4
# 'Fraction(numerator=1, denominator=4)'

# %%
'''
10. Research other types of gates that exist (such as NAND, NOR, and XOR). Add them to the circuit hierarchy. 
    How much additional coding did you need to do? done

11. The most simple arithmetic circuit is known as the half-adder. Research the simple half-adder circuit. Implement this circuit. done

12. Now extend that circuit and implement an 8 bit full-adder. research

13. The circuit simulation shown in this chapter works in a backward direction. 
    In other words, given a circuit, the output is produced by working back through the input values, which in turn cause other outputs to be queried. 
    This continues until external input lines are found, at which point the user is asked for values. 
    Modify the implementation so that the action is in the forward direction; upon receiving inputs the circuit produces an output.
'''
class LogicGate:
    def __init__(self,n):
        self.name = n
        self.output = None

    def getLabel(self):
        return self.name

    def getOutput(self):
        self.output = self.performGateLogic()
        return self.output


class BinaryGate(LogicGate):

    def __init__(self,n):
        super(BinaryGate, self).__init__(n)

        self.pinA = None
        self.pinB = None

    def getPinA(self):
        if self.pinA == None:
            return int(input("Enter Pin A input for gate "+self.getLabel()+"-->"))
        else:
            return self.pinA.getFrom().getOutput()

    def getPinB(self):
        if self.pinB == None:
            return int(input("Enter Pin B input for gate "+self.getLabel()+"-->"))
        else:
            return self.pinB.getFrom().getOutput()

    def setNextPin(self,source):
        if self.pinA == None:
            self.pinA = source
        else:
            if self.pinB == None:
                self.pinB = source
            else:
                print("Cannot Connect: NO EMPTY PINS on this gate")


class AndGate(BinaryGate):

    def __init__(self,n):
        BinaryGate.__init__(self,n)

    def performGateLogic(self):

        a = self.getPinA()
        b = self.getPinB()
        if a==1 and b==1:
            return 1
        else:
            return 0

class OrGate(BinaryGate):

    def __init__(self,n):
        BinaryGate.__init__(self,n)

    def performGateLogic(self):

        a = self.getPinA()
        b = self.getPinB()
        if a ==1 or b==1:
            return 1
        else:
            return 0

class XOrGate(BinaryGate):

    def __init__(self,n):
        BinaryGate.__init__(self,n)

    def performGateLogic(self):

        a = self.getPinA()
        b = self.getPinB()
        if (a ==1 and b==1) or (a == 0 and b == 0):
            return 0
        else:
            return 1
        
class NandGate(AndGate):
    def performGateLogic(self):
        if super().performGateLogic() == 1:
            return 0
        else:
            return 1

class NorGate(OrGate):

    def performGateLogic(self):
        if super().performGateLogic() == 1:
            return 0
        else:
            return 1
class XNorGate(XOrGate):
    def performGateLogic(self):
        if super().performGateLogic() == 1:
            return 0
        else:
            return 1
            
class UnaryGate(LogicGate):

    def __init__(self,n):
        LogicGate.__init__(self,n)

        self.pin = None

    def getPin(self):
        if self.pin == None:
            return int(input("Enter Pin input for gate "+self.getLabel()+"-->"))
        else:
            return self.pin.getFrom().getOutput()

    def setNextPin(self,source):
        if self.pin == None:
            self.pin = source
        else:
            print("Cannot Connect: NO EMPTY PINS on this gate")


class NotGate(UnaryGate):

    def __init__(self,n):
        UnaryGate.__init__(self,n)

    def performGateLogic(self):
        if self.getPin():
            return 0
        else:
            return 1


class Connector:

    def __init__(self, fgate, tgate):
        self.fromgate = fgate
        self.togate = tgate

        tgate.setNextPin(self)

    def getFrom(self):
        return self.fromgate

    def getTo(self):
        return self.togate
    
    
def main():
    xa= XNorGate("xa")
    print(f"xa output {xa.getOutput()}")
## half_adder
    g1 = AndGate("g1")
    g2 = OrGate("g2")
    sum = XOrGate("sum")
    carry = AndGate("carry")
    c1 = Connector(g1, sum)
    c2 = Connector(g2, sum)
    c3 = Connector(g1, carry)
    c4 = Connector(g2, carry)
    print(f"sum = {sum.getOutput()} and carry = {carry.getOutput()}")
    
main()
# Out:
# Enter Pin A input for gate xa--> 1
# Enter Pin B input for gate xa--> 0
# xa output 0
# Enter Pin A input for gate g1--> 1
# Enter Pin B input for gate g1--> 1
# Enter Pin A input for gate g2--> 1
# Enter Pin B input for gate g2--> 1
# Enter Pin A input for gate g1--> 1
# Enter Pin B input for gate g1--> 1
# Enter Pin A input for gate g2--> 1
# Enter Pin B input for gate g2--> 1
# sum = 0 and carry = 1
